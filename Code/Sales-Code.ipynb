# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
file_path = "/Users/jennanowland/Desktop/Data_400/Data400_Final/Data-Files/Pepsi-Coke-Sales-Data.xlsx"
xls = pd.ExcelFile(file_path)


sheet_names = xls.sheet_names


df_Pepsi = pd.read_excel(xls, sheet_name=sheet_names[1])  
df_Coke = pd.read_excel(xls, sheet_name=sheet_names[2])  



#print(df_Pepsi.head())
#print(df_Coke.head())

# %%
df_Pepsi
# Out:
#     Year Considered  First Quarter Revenue (in Millions)  \
# 0              2012                                12428
# 1              2013                                12581
# 2              2014                                12623
# 3              2015                                12217
# 4              2016                                11862
# 5              2017                                12049
# 6              2018                                12562
# 7              2019                                12884
# 8              2020                                13881
# 9              2021                                14820
# 10             2022                                16200
#
#     Last Quarter Revenue (in Millions)  Total Revenue (in Millions)
# 0                                19954                        65492
# 1                                20118                        66415
# 2                                19948                        66683
# 3                                18585                        63056
# 4                                19515                        62799
# 5                                19526                        63525
# 6                                19524                        64661
# 7                                20640                        67161
# 8                                22455                        70372
# 9                                25248                        79474
# 10                               27996                        86392

# %%
df_Coke
# Out:
#     Year Considered  First Quarter Revenue (in Millions)  \
# 0              2012                                11137
# 1              2013                                11035
# 2              2014                                10576
# 3              2015                                10771
# 4              2016                                10282
# 5              2017                                 9118
# 6              2018                                 7626
# 7              2019                                 8694
# 8              2020                                 8601
# 9              2021                                 9020
# 10             2022                                10491
#
#     Last Quarter Revenue (in Millions)  Total Revenue (in Millions)
# 0                                11455                        48017
# 1                                11040                        46854
# 2                                10872                        45998
# 3                                10000                        44294
# 4                                 9409                        41863
# 5                                 8314                        36212
# 6                                 8478                        34300
# 7                                 9068                        37266
# 8                                 8611                        33014
# 9                                 9464                        38655
# 10                               10125                        43004

# %%
df_Pepsi['Pepsi_Percent_Change_Rev'] = ((df_Pepsi['Last Quarter Revenue (in Millions)'] - df_Pepsi['First Quarter Revenue (in Millions)']) / df_Pepsi['First Quarter Revenue (in Millions)']) * 100


df_Pepsi
# Out:
#     Year Considered  First Quarter Revenue (in Millions)  \
# 0              2012                                12428
# 1              2013                                12581
# 2              2014                                12623
# 3              2015                                12217
# 4              2016                                11862
# 5              2017                                12049
# 6              2018                                12562
# 7              2019                                12884
# 8              2020                                13881
# 9              2021                                14820
# 10             2022                                16200
#
#     Last Quarter Revenue (in Millions)  Total Revenue (in Millions)  \
# 0                                19954                        65492
# 1                                20118                        66415
# 2                                19948                        66683
# 3                                18585                        63056
# 4                                19515                        62799
# 5                                19526                        63525
# 6                                19524                        64661
# 7                                20640                        67161
# 8                                22455                        70372
# 9                                25248                        79474
# 10                               27996                        86392
#
#     Pepsi_Percent_Change_Rev
# 0                  60.556807
# 1                  59.907797
# 2                  58.028995
# 3                  52.124089
# 4                  64.516945
# 5                  62.054942
# 6                  55.421111
# 7                  60.198696
# 8                  61.767884
# 9                  70.364372
# 10                 72.814815

# %%
df_Coke['Coke_Percent_Change_Rev'] = ((df_Coke['Last Quarter Revenue (in Millions)'] - df_Coke['First Quarter Revenue (in Millions)']) / df_Coke['First Quarter Revenue (in Millions)']) * 100


df_Coke
# Out:
#     Year Considered  First Quarter Revenue (in Millions)  \
# 0              2012                                11137
# 1              2013                                11035
# 2              2014                                10576
# 3              2015                                10771
# 4              2016                                10282
# 5              2017                                 9118
# 6              2018                                 7626
# 7              2019                                 8694
# 8              2020                                 8601
# 9              2021                                 9020
# 10             2022                                10491
#
#     Last Quarter Revenue (in Millions)  Total Revenue (in Millions)  \
# 0                                11455                        48017
# 1                                11040                        46854
# 2                                10872                        45998
# 3                                10000                        44294
# 4                                 9409                        41863
# 5                                 8314                        36212
# 6                                 8478                        34300
# 7                                 9068                        37266
# 8                                 8611                        33014
# 9                                 9464                        38655
# 10                               10125                        43004
#
#     Coke_Percent_Change_Rev
# 0                  2.855347
# 1                  0.045310
# 2                  2.798790
# 3                 -7.158110
# 4                 -8.490566
# 5                 -8.817723
# 6                 11.172305
# 7                  4.301817
# 8                  0.116266
# 9                  4.922395
# 10                -3.488705

# %%
# Set Seaborn style
sns.set(style="whitegrid")

### 1. Line Plot: Revenue Changes Over Time ###
plt.figure(figsize=(10, 5))
plt.plot(df_Pepsi['Year Considered'], df_Pepsi['Last Quarter Revenue (in Millions)'], marker='o', label='Pepsi Revenue (Q4)', color='red')
plt.plot(df_Pepsi['Year Considered'], df_Pepsi['First Quarter Revenue (in Millions)'], marker='s', label='Pepsi Revenue (Q1)', color='blue')
plt.xlabel("Year")
plt.ylabel("Revenue (in Millions)")
plt.title("Pepsi Revenue Over Time")
plt.legend()
plt.xticks(df_Pepsi['Year Considered'])
plt.show()

# %%
# Set Seaborn style
sns.set(style="whitegrid")

### 1. Line Plot: Revenue Changes Over Time ###
plt.figure(figsize=(10, 5))
plt.plot(df_Coke['Year Considered'], df_Coke['Last Quarter Revenue (in Millions)'], marker='o', label='Coke Revenue (Q4)', color='red')
plt.plot(df_Coke['Year Considered'], df_Coke['First Quarter Revenue (in Millions)'], marker='s', label='Coke Revenue (Q1)', color='blue')
plt.xlabel("Year")
plt.ylabel("Revenue (in Millions)")
plt.title("Coke Revenue Over Time")
plt.legend()
plt.xticks(df_Coke['Year Considered'])
plt.show()

# %%
df_combined = pd.concat([df_Pepsi, df_Coke], axis=1)
print(df_combined)
# Out:
#     Year Considered  First Quarter Revenue (in Millions)  \
# 0              2012                                12428
# 1              2013                                12581
# 2              2014                                12623
# 3              2015                                12217
# 4              2016                                11862
# 5              2017                                12049
# 6              2018                                12562
# 7              2019                                12884
# 8              2020                                13881
# 9              2021                                14820
# 10             2022                                16200
#
#     Last Quarter Revenue (in Millions)  Total Revenue (in Millions)  \
# 0                                19954                        65492
# 1                                20118                        66415
# 2                                19948                        66683
# 3                                18585                        63056
# 4                                19515                        62799
# 5                                19526                        63525
# 6                                19524                        64661
# 7                                20640                        67161
# 8                                22455                        70372
# 9                                25248                        79474
# 10                               27996                        86392
#
#     Pepsi_Percent_Change_Rev  Year Considered  \
# 0                  60.556807             2012
# 1                  59.907797             2013
# 2                  58.028995             2014
# 3                  52.124089             2015
# 4                  64.516945             2016
# 5                  62.054942             2017
# 6                  55.421111             2018
# 7                  60.198696             2019
# 8                  61.767884             2020
# 9                  70.364372             2021
# 10                 72.814815             2022
#
#     First Quarter Revenue (in Millions)  Last Quarter Revenue (in Millions)  \
# 0                                 11137                               11455
# 1                                 11035                               11040
# 2                                 10576                               10872
# 3                                 10771                               10000
# 4                                 10282                                9409
# 5                                  9118                                8314
# 6                                  7626                                8478
# 7                                  8694                                9068
# 8                                  8601                                8611
# 9                                  9020                                9464
# 10                                10491                               10125
#
#     Total Revenue (in Millions)  Coke_Percent_Change_Rev
# 0                         48017                 2.855347
# 1                         46854                 0.045310
# 2                         45998                 2.798790
# 3                         44294                -7.158110
# 4                         41863                -8.490566
# 5                         36212                -8.817723
# 6                         34300                11.172305
# 7                         37266                 4.301817
# 8                         33014                 0.116266
# 9                         38655                 4.922395
# 10                        43004                -3.488705

# %%
# Get column names
columns = df_combined.columns.to_list()

# Define the Pepsi and Coke column names
labels = ["Year Considered", "First Quarter Revenue (in Millions)", 
          "Last Quarter Revenue (in Millions)", "Total Revenue (in Millions)"]

# Initialize counts
pepsi_count = 0
coke_count = 0

# Create new column names
new_columns = []

for col in columns:
    if col in labels:
        if pepsi_count < len(labels):  
            new_columns.append(f"Pepsi_{col.replace(' (in Millions)', '').replace(' ', '_')}")
            pepsi_count += 1
        else:
            new_columns.append(f"Coke_{col.replace(' (in Millions)', '').replace(' ', '_')}")
            coke_count += 1
    else:
        new_columns.append(col)  # Keep unchanged

# Assign new column names
df_combined.columns = new_columns

# Display the renamed columns
print(df_combined.head())
# Out:
#    Pepsi_Year_Considered  Pepsi_First_Quarter_Revenue  \
# 0                   2012                        12428
# 1                   2013                        12581
# 2                   2014                        12623
# 3                   2015                        12217
# 4                   2016                        11862
#
#    Pepsi_Last_Quarter_Revenue  Pepsi_Total_Revenue  Pepsi_Percent_Change_Rev  \
# 0                       19954                65492                 60.556807
# 1                       20118                66415                 59.907797
# 2                       19948                66683                 58.028995
# 3                       18585                63056                 52.124089
# 4                       19515                62799                 64.516945
#
#    Coke_Year_Considered  Coke_First_Quarter_Revenue  \
# 0                  2012                       11137
# 1                  2013                       11035
# 2                  2014                       10576
# 3                  2015                       10771
# 4                  2016                       10282
#
#    Coke_Last_Quarter_Revenue  Coke_Total_Revenue  Coke_Percent_Change_Rev
# 0                      11455               48017                 2.855347
# 1                      11040               46854                 0.045310
# 2                      10872               45998                 2.798790
# 3                      10000               44294                -7.158110
# 4                       9409               41863                -8.490566

# %%
df_combined
# Out:
#     Pepsi_Year_Considered  Pepsi_First_Quarter_Revenue  \
# 0                    2012                        12428
# 1                    2013                        12581
# 2                    2014                        12623
# 3                    2015                        12217
# 4                    2016                        11862
# 5                    2017                        12049
# 6                    2018                        12562
# 7                    2019                        12884
# 8                    2020                        13881
# 9                    2021                        14820
# 10                   2022                        16200
#
#     Pepsi_Last_Quarter_Revenue  Pepsi_Total_Revenue  Pepsi_Percent_Change_Rev  \
# 0                        19954                65492                 60.556807
# 1                        20118                66415                 59.907797
# 2                        19948                66683                 58.028995
# 3                        18585                63056                 52.124089
# 4                        19515                62799                 64.516945
# 5                        19526                63525                 62.054942
# 6                        19524                64661                 55.421111
# 7                        20640                67161                 60.198696
# 8                        22455                70372                 61.767884
# 9                        25248                79474                 70.364372
# 10                       27996                86392                 72.814815
#
#     Coke_Year_Considered  Coke_First_Quarter_Revenue  \
# 0                   2012                       11137
# 1                   2013                       11035
# 2                   2014                       10576
# 3                   2015                       10771
# 4                   2016                       10282
# 5                   2017                        9118
# 6                   2018                        7626
# 7                   2019                        8694
# 8                   2020                        8601
# 9                   2021                        9020
# 10                  2022                       10491
#
#     Coke_Last_Quarter_Revenue  Coke_Total_Revenue  Coke_Percent_Change_Rev
# 0                       11455               48017                 2.855347
# 1                       11040               46854                 0.045310
# 2                       10872               45998                 2.798790
# 3                       10000               44294                -7.158110
# 4                        9409               41863                -8.490566
# 5                        8314               36212                -8.817723
# 6                        8478               34300                11.172305
# 7                        9068               37266                 4.301817
# 8                        8611               33014                 0.116266
# 9                        9464               38655                 4.922395
# 10                      10125               43004                -3.488705

# %%
# Set Seaborn style
sns.set(style="whitegrid")

### 1. Line Plot: Revenue Changes Over Time ###
plt.figure(figsize=(10, 5))
plt.plot(df_combined['Pepsi_Year_Considered'], df_combined['Pepsi_First_Quarter_Revenue'], marker='o', label='Pepsi Revenue (Q1)', color='blue')
plt.plot(df_combined['Coke_Year_Considered'], df_combined['Coke_First_Quarter_Revenue'], marker='s', label='Coke Revenue (Q1)', color='red')
plt.xlabel("Year")
plt.ylabel("Revenue (in Millions)")
plt.title("Coke vs Pepsi Revenue Q1 Over Time")
plt.legend()
plt.xticks(df_combined['Pepsi_Year_Considered'])
plt.show()

# %%
# Set Seaborn style
sns.set(style="whitegrid")

### 1. Line Plot: Revenue Changes Over Time ###
plt.figure(figsize=(10, 5))
plt.plot(df_combined['Pepsi_Year_Considered'], df_combined['Pepsi_Last_Quarter_Revenue'], marker='o', label='Pepsi Revenue (Q4)', color='blue')
plt.plot(df_combined['Coke_Year_Considered'], df_combined['Coke_Last_Quarter_Revenue'], marker='s', label='Coke Revenue (Q4)', color='red')
plt.xlabel("Year")
plt.ylabel("Revenue (in Millions)")
plt.title("Coke vs Pepsi Revenue Q4 Over Time")
plt.legend()
plt.xticks(df_combined['Pepsi_Year_Considered'])
plt.show()

# %%
# Set Seaborn style
sns.set(style="whitegrid")

### 1. Line Plot: Revenue Changes Over Time ###
plt.figure(figsize=(10, 5))
plt.plot(df_combined['Pepsi_Year_Considered'], df_combined['Pepsi_Last_Quarter_Revenue'], marker='o', label='Pepsi Revenue (Q4)', color='purple')
plt.plot(df_combined['Coke_Year_Considered'], df_combined['Coke_Last_Quarter_Revenue'], marker='s', label='Coke Revenue (Q4)', color='red')
plt.plot(df_combined['Pepsi_Year_Considered'], df_combined['Pepsi_First_Quarter_Revenue'], marker='o', label='Pepsi Revenue (Q1)', color='blue')
plt.plot(df_combined['Coke_Year_Considered'], df_combined['Coke_First_Quarter_Revenue'], marker='s', label='Coke Revenue (Q1)', color='orange')


plt.xlabel("Year")
plt.ylabel("Revenue (in Millions)")
plt.title("Coke vs Pepsi Revenue Over Time")
plt.legend()
plt.xticks(df_combined['Pepsi_Year_Considered'])
plt.show()

# %%
# Define the independent and dependent variables for Pepsi
X_pepsi = df_combined[['Pepsi_First_Quarter_Revenue']]  # Predictor (Q1 revenue)
Y_pepsi = df_combined['Pepsi_Last_Quarter_Revenue']  # Target (Q4 revenue)

# Add a constant for the intercept in the regression model
X_pepsi = sm.add_constant(X_pepsi)

# Create and fit the regression model for Pepsi
model_pepsi = sm.OLS(Y_pepsi, X_pepsi).fit()

# Print Pepsi regression summary
print("Pepsi Regression Results:")
print(model_pepsi.summary())

# Define the independent and dependent variables for Coke
X_coke = df_combined[['Coke_First_Quarter_Revenue']]  # Predictor (Q1 revenue)
Y_coke = df_combined['Coke_Last_Quarter_Revenue']  # Target (Q4 revenue)

# Add a constant for the intercept
X_coke = sm.add_constant(X_coke)

# Create and fit the regression model for Coke
model_coke = sm.OLS(Y_coke, X_coke).fit()

# Print Coke regression summary
print("\nCoca-Cola Regression Results:")
print(model_coke.summary())
# Out:
# Pepsi Regression Results:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Pepsi_Last_Quarter_Revenue   R-squared:                       0.970
# Model:                                    OLS   Adj. R-squared:                  0.967
# Method:                         Least Squares   F-statistic:                     294.8
# Date:                        Thu, 27 Mar 2025   Prob (F-statistic):           3.47e-08
# Time:                                09:25:06   Log-Likelihood:                -83.421
# No. Observations:                          11   AIC:                             170.8
# Df Residuals:                               9   BIC:                             171.6
# Df Model:                                   1
# Covariance Type:                    nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                       -6748.9325   1637.033     -4.123      0.003   -1.05e+04   -3045.705
# Pepsi_First_Quarter_Revenue     2.1355      0.124     17.171      0.000       1.854       2.417
# ==============================================================================
# Omnibus:                        0.237   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.888   Jarque-Bera (JB):                0.325
# Skew:                           0.265   Prob(JB):                        0.850
# Kurtosis:                       2.345   Cond. No.                     1.36e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.36e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Coca-Cola Regression Results:
#                                 OLS Regression Results
# =====================================================================================
# Dep. Variable:     Coke_Last_Quarter_Revenue   R-squared:                       0.761
# Model:                                   OLS   Adj. R-squared:                  0.735
# Method:                        Least Squares   F-statistic:                     28.72
# Date:                       Thu, 27 Mar 2025   Prob (F-statistic):           0.000457
# Time:                               09:25:06   Log-Likelihood:                -84.032
# No. Observations:                         11   AIC:                             172.1
# Df Residuals:                              9   BIC:                             172.9
# Df Model:                                  1
# Covariance Type:                   nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                       1944.1709   1459.146      1.332      0.215   -1356.648    5244.989
# Coke_First_Quarter_Revenue     0.7960      0.149      5.359      0.000       0.460       1.132
# ==============================================================================
# Omnibus:                        1.686   Durbin-Watson:                   1.383
# Prob(Omnibus):                  0.430   Jarque-Bera (JB):                1.032
# Skew:                          -0.459   Prob(JB):                        0.597
# Kurtosis:                       1.814   Cond. No.                     8.55e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.55e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Users/jennanowland/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# /Users/jennanowland/anaconda3/lib/python3.11/site-packages/scipy/stats/_stats_py.py:1806: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=11
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# Rename the necessary columns for simplicity
df_combined = df_combined.rename(columns={
    'Pepsi_First_Quarter_Revenue': 'Pepsi_Q1',
    'Pepsi_Last_Quarter_Revenue': 'Pepsi_Q4',
    'Coke_First_Quarter_Revenue': 'Coke_Q1',
    'Coke_Last_Quarter_Revenue': 'Coke_Q4'
})

plt.figure(figsize=(7, 5))

# Scatter Plot
sns.scatterplot(x=df_combined['Coke_Q1'], y=df_combined['Coke_Q4'], color='red', label='Coca-Cola')
sns.scatterplot(x=df_combined['Pepsi_Q1'], y=df_combined['Pepsi_Q4'], color='blue', label='Pepsi')

# Fit regression line using statsmodels
for company, color in [('Coke', 'red'), ('Pepsi', 'blue')]:
    X = df_combined[f'{company}_Q1']
    Y = df_combined[f'{company}_Q4']
    X = sm.add_constant(X)  # Add constant for regression
    model = sm.OLS(Y, X).fit()
    predicted = model.predict(X)
    plt.plot(df_combined[f'{company}_Q1'], predicted, color=color, linestyle='--')

plt.xlabel("First Quarter Revenue")
plt.ylabel("Last Quarter Revenue")
plt.title("Q1 vs Q4 Revenue with Regression Line")
plt.legend()
plt.show()





########################################################################################################

# Interpretation 

## Positive Slope: If the regression line is upward-sloping, it means that when Q1 revenue increases, Q4 revenue also tends to increase.

## Flatter Line: If the regression line is flatter, it suggests a weaker relationship between Q1 and Q4 revenue.

## Both companies follow similar revenue trends but Pepsi’s line is steeper than Coke’s, so Pepsi’s Q4 revenue is more strongly tied to Q1 revenue.
